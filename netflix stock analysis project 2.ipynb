# %% [markdown]
# # netflix stock analysis project

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
 df = pd.read_csv("NFLX.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.set(rc = {'figure.figsize' : (10,5)})

# %%
df = df.reset_index()

df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.lineplot(x=df.index, y=df['Volume'], label='Volume')
plt.title('Volume of Stock versus Time')
plt.show()

# %%
df.plot(y =  ['High','Close','Open'],title = 'netflix stock price')
# Out:
# <Axes: title={'center': 'netflix stock price'}, xlabel='Date'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize = (15, 10))
df.groupby(df.index.day).mean().plot( y = 'Volume', ax=ax1, xlabel = 'Day')
df.groupby(df.index.month).mean().plot(y = 'Volume', ax = ax2, xlabel='Month')
df.groupby(df.index.year).mean().plot(y = 'Volume', ax = ax3 , xlabel ='year' )
# Out:
# <Axes: xlabel='year'>

# %%
a = df.sort_values(by='High', ascending=False).head(5)
a['High']
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...                ...         ...         ...         ...         ...
# 2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# 2002-05-29    6757800
# 2002-05-30   10154200
# ...               ...
# 2022-05-27    8586000
# 2022-05-31   11398500
# 2022-06-01    8416200
# 2022-06-02    9623100
# 2022-06-03    7181700
#
# [5044 rows x 6 columns]

# %%
b = df.sort_values(by='Low', ascending=True).head(5)
b['Low']
# Out:
# Date
# 2002-10-10    0.346429
# 2002-10-09    0.347143
# 2002-10-07    0.382143
# 2002-10-08    0.390714
# 2002-10-16    0.442857
# Name: Low, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1 row aur 2 columns ka layout banana
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Pehla graph (Left side - axes[0])
sns.lineplot(ax=axes[0], x=df.index, y=df['High'], color='green')
axes[0].set_title('High Prices')

# Dusra graph (Right side - axes[1])
sns.lineplot(ax=axes[1], x=df.index, y=df['Low'], color='red')
axes[1].set_title('Low Prices')

plt.tight_layout()
plt.show()
